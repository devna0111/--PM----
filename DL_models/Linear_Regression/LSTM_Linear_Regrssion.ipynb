# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:130px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:130px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %%
import pandas as pd
import numpy as np
import joblib
from datetime import datetime, timedelta
import holidays
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import f1_score,precision_score, recall_score
import seaborn as sns
plt.rc('font',family = 'Hancom Gothic')

# %% [markdown]
# # 데이터 체크 및 전처리

# %%
# 데이터 로딩 및 전처리
df = pd.read_csv('LSTM최종데이터_X_Y_라벨링등전.csv')
df = df.dropna(subset=['대여량']) # 혹시 모를 결측치 제거 코드 _ 결측치 사전 체크 : 결과 0건

df['일시'] = pd.to_datetime(df['일시'])
df['연'] = df['일시'].dt.year
df['월'] = df['일시'].dt.month
df['일'] = df['일시'].dt.day
df['시'] = df['일시'].dt.hour
df['요일'] = df['일시'].dt.dayofweek
start_year = df['연'].min()
end_year = df['연'].max()
kr_holidays = holidays.KR(years=range(start_year, end_year+1)) # 한국 공휴일 체크 라이브러리
df['공휴일'] = df['일시'].dt.floor('D').isin(kr_holidays).astype(int)

df['key'] = df['행정구'] + '_' + df['월'].astype(str) + '_' + df['일'].astype(str) + '_' + df['시'].astype(str)
df['일시_1년전'] = df['일시'] - pd.DateOffset(years=1)
df['key_1년전'] = df['행정구'] + '_' + df['일시_1년전'].dt.month.astype(str) + '_' + df['일시_1년전'].dt.day.astype(str) + '_' + df['일시_1년전'].dt.hour.astype(str)
cols_to_copy = ['대여량', '총생활인구수']
df_1y = df[cols_to_copy].copy()
df_1y.columns = [c + '_1년전' for c in cols_to_copy]
df = pd.concat((df,df_1y), axis=1)
df = df.dropna(subset=['대여량_1년전', '총생활인구수_1년전'])

df
# Out:
#           연도   월   일   시  행정구  ...           key              일시_1년전       key_1년전 대여량_1년전   총생활인구수_1년전
# 0       2021   1   1   0  강남구  ...     강남구_1_1_0 2020-01-01 00:00:00     강남구_1_1_0     9.0  618455.4297
# 1       2021   1   1   0  강동구  ...     강동구_1_1_0 2020-01-01 00:00:00     강동구_1_1_0    12.0  525220.6638
# 2       2021   1   1   0  강북구  ...     강북구_1_1_0 2020-01-01 00:00:00     강북구_1_1_0    12.0  321499.2460
# 3       2021   1   1   0  강서구  ...     강서구_1_1_0 2020-01-01 00:00:00     강서구_1_1_0    27.0  547287.6699
# 4       2021   1   1   0  관악구  ...     관악구_1_1_0 2020-01-01 00:00:00     관악구_1_1_0    19.0  492742.3420
# ...      ...  ..  ..  ..  ...  ...           ...                 ...           ...     ...          ...
# 872088  2024  12  31  23  용산구  ...  용산구_12_31_23 2023-12-31 23:00:00  용산구_12_31_23    37.0  253261.4373
# 872089  2024  12  31  23  은평구  ...  은평구_12_31_23 2023-12-31 23:00:00  은평구_12_31_23    35.0  453205.9782
# 872090  2024  12  31  23  종로구  ...  종로구_12_31_23 2023-12-31 23:00:00  종로구_12_31_23    81.0  231161.5069
# 872091  2024  12  31  23   중구  ...   중구_12_31_23 2023-12-31 23:00:00   중구_12_31_23    77.0  172509.0426
# 872092  2024  12  31  23  중랑구  ...  중랑구_12_31_23 2023-12-31 23:00:00  중랑구_12_31_23    57.0  353699.9845
#
# [872093 rows x 23 columns]

# %%
# 데이터 전처리 _ 라벨링 및 스케일링
from sklearn.preprocessing import LabelEncoder, StandardScaler
pd.options.mode.copy_on_write = True 
le = LabelEncoder()
df['행정구'] = le.fit_transform(df['행정구'])

feature_cols = [
    '행정구', '월', '일', '시', '요일', '강수', '기온', '습도', '풍속',
    '주말구분', '공휴일',
    '대여량_1년전', '총생활인구수_1년전',
]
X = df[feature_cols]
y = df['대여량']

num_cols = [ '강수', '기온', '습도', '풍속',
    '대여량_1년전', '총생활인구수_1년전',]
scaler = StandardScaler()
X[num_cols] = scaler.fit_transform(X[num_cols])

# %%
X.shape, y.shape
# Out:
# ((872093, 13), (872093,))

# %%
# 데이터 분할 : 22년 학습, 23년 검증, 24년 테스트 활용
train_idx = df['연'] == 2022
val_idx = (df['연'] == 2023)
test_idx = (df['연'] == 2024)
X_train, X_val, X_test = X[train_idx], X[val_idx], X[test_idx]
y_train, y_val, y_test = y[train_idx], y[val_idx], y[test_idx]

# %%
# 데이터 LSTM용 설계
X_train = np.expand_dims(X_train,axis=1)
X_val = np.expand_dims(X_val,axis=1)
X_test = np.expand_dims(X_test,axis=1)
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((217520, 1, 13), (218234, 1, 13), (218914, 1, 13))

# %% [markdown]
# # 모델 설계

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Dense, Dropout, LSTM

# 예시: X.shape = (샘플수, time_steps, features)
Inp = Input(shape=(X_train.shape[1], X_train.shape[2]))   # (time_steps, features)

x = LSTM(128, return_sequences=True)(Inp)
x = Dropout(0.2)(x)
x = LSTM(64)(x)
x = Dropout(0.2)(x)
x = Dense(128, activation='relu')(x)
Out = Dense(1, activation='relu')(x)

model_lstm = Model(inputs=Inp, outputs=Out)

model_lstm.compile(loss='mse', optimizer='adam', metrics=['mae'])

model_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1, 13)]           0
#
#  lstm (LSTM)                 (None, 1, 128)            72704
#
#  dropout (Dropout)           (None, 1, 128)            0
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 128)               8320
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 130,561
# Trainable params: 130,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 모델 학습

# %%
es = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)
mc = ModelCheckpoint('best_lstm_model_lr.h5', monitor='val_loss', save_best_only=True, verbose=1)
history = model_lstm.fit(
    X_train, y_train,
    epochs=100,
    batch_size=512,
    validation_data=(X_val, y_val),
    callbacks=[es, mc],
    verbose=2
)
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 11537.76660, saving model to best_lstm_model_lr.h5
# 425/425 - 8s - loss: 35016.8672 - mae: 88.5191 - val_loss: 11537.7666 - val_mae: 24.3034 - 8s/epoch - 19ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 11537.76660 to 3278.12378, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 4150.6538 - mae: 22.4642 - val_loss: 3278.1238 - val_mae: 9.9479 - 3s/epoch - 7ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 3278.12378 to 1432.01367, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 1583.7710 - mae: 16.7647 - val_loss: 1432.0137 - val_mae: 7.2641 - 3s/epoch - 7ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1432.01367 to 792.23206, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 949.0875 - mae: 14.8473 - val_loss: 792.2321 - val_mae: 5.8680 - 3s/epoch - 7ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 792.23206 to 451.29169, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 700.2242 - mae: 13.7080 - val_loss: 451.2917 - val_mae: 4.8465 - 3s/epoch - 7ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 451.29169 to 330.48843, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 584.1683 - mae: 13.0758 - val_loss: 330.4884 - val_mae: 6.1166 - 3s/epoch - 7ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 330.48843 to 255.85332, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 530.0393 - mae: 12.6396 - val_loss: 255.8533 - val_mae: 6.3546 - 3s/epoch - 7ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 255.85332 to 238.91978, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 495.3681 - mae: 12.3277 - val_loss: 238.9198 - val_mae: 6.9264 - 3s/epoch - 7ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 238.91978 to 168.41393, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 448.6277 - mae: 11.8249 - val_loss: 168.4139 - val_mae: 3.4960 - 3s/epoch - 7ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 168.41393 to 167.81909, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 433.1299 - mae: 11.4563 - val_loss: 167.8191 - val_mae: 6.5881 - 3s/epoch - 7ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 167.81909 to 126.69260, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 435.1558 - mae: 11.6578 - val_loss: 126.6926 - val_mae: 5.8832 - 3s/epoch - 7ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 126.69260 to 124.82226, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 412.6158 - mae: 11.0690 - val_loss: 124.8223 - val_mae: 4.7310 - 3s/epoch - 7ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 124.82226 to 88.59928, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 383.2224 - mae: 10.7886 - val_loss: 88.5993 - val_mae: 3.2109 - 3s/epoch - 7ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 88.59928
# 425/425 - 3s - loss: 380.2761 - mae: 10.7470 - val_loss: 120.6351 - val_mae: 6.3877 - 3s/epoch - 7ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 88.59928
# 425/425 - 3s - loss: 372.7785 - mae: 10.5970 - val_loss: 135.2623 - val_mae: 7.1920 - 3s/epoch - 7ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 88.59928 to 69.66783, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 356.2372 - mae: 10.4287 - val_loss: 69.6678 - val_mae: 3.9627 - 3s/epoch - 7ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 69.66783
# 425/425 - 3s - loss: 356.2228 - mae: 10.4071 - val_loss: 113.9164 - val_mae: 6.2144 - 3s/epoch - 7ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 69.66783
# 425/425 - 3s - loss: 334.9736 - mae: 10.0612 - val_loss: 127.9739 - val_mae: 6.0597 - 3s/epoch - 7ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 69.66783 to 69.52116, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 332.6239 - mae: 10.0787 - val_loss: 69.5212 - val_mae: 3.6565 - 3s/epoch - 7ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 69.52116 to 53.60344, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 317.2933 - mae: 9.8987 - val_loss: 53.6034 - val_mae: 3.6814 - 3s/epoch - 7ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 53.60344 to 47.70021, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 327.8792 - mae: 9.9171 - val_loss: 47.7002 - val_mae: 2.8883 - 3s/epoch - 7ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 47.70021
# 425/425 - 3s - loss: 310.2058 - mae: 9.6815 - val_loss: 81.7539 - val_mae: 4.7340 - 3s/epoch - 7ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 47.70021
# 425/425 - 3s - loss: 310.7424 - mae: 9.8347 - val_loss: 93.0893 - val_mae: 6.2275 - 3s/epoch - 7ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 47.70021
# 425/425 - 3s - loss: 303.1402 - mae: 9.7545 - val_loss: 80.5628 - val_mae: 6.1652 - 3s/epoch - 7ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 47.70021
# 425/425 - 3s - loss: 301.9055 - mae: 9.7213 - val_loss: 52.3416 - val_mae: 3.2981 - 3s/epoch - 7ms/step
# Epoch 26/100
#
# Epoch 26: val_loss improved from 47.70021 to 44.81300, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 285.4081 - mae: 9.5257 - val_loss: 44.8130 - val_mae: 3.2084 - 3s/epoch - 7ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 44.81300
# 425/425 - 3s - loss: 279.6236 - mae: 9.4057 - val_loss: 82.9891 - val_mae: 6.2756 - 3s/epoch - 7ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 44.81300 to 42.52871, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 282.8380 - mae: 9.4021 - val_loss: 42.5287 - val_mae: 3.1313 - 3s/epoch - 7ms/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 42.52871 to 39.27970, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 288.2571 - mae: 9.5235 - val_loss: 39.2797 - val_mae: 2.8614 - 3s/epoch - 7ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 39.27970
# 425/425 - 3s - loss: 274.5063 - mae: 9.3584 - val_loss: 50.5127 - val_mae: 3.4889 - 3s/epoch - 7ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 39.27970
# 425/425 - 3s - loss: 277.7663 - mae: 9.3586 - val_loss: 51.7166 - val_mae: 4.0184 - 3s/epoch - 7ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 39.27970
# 425/425 - 3s - loss: 272.5088 - mae: 9.4052 - val_loss: 95.0548 - val_mae: 5.1498 - 3s/epoch - 7ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 39.27970
# 425/425 - 3s - loss: 273.7042 - mae: 9.3653 - val_loss: 48.9009 - val_mae: 3.4464 - 3s/epoch - 7ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 39.27970
# 425/425 - 3s - loss: 263.3905 - mae: 9.1345 - val_loss: 91.1083 - val_mae: 5.0444 - 3s/epoch - 7ms/step
# Epoch 35/100
#
# Epoch 35: val_loss improved from 39.27970 to 35.51285, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 261.4658 - mae: 9.1590 - val_loss: 35.5129 - val_mae: 3.0985 - 3s/epoch - 7ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 35.51285
# 425/425 - 3s - loss: 255.2978 - mae: 8.9835 - val_loss: 87.8467 - val_mae: 4.8845 - 3s/epoch - 7ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 35.51285
# 425/425 - 3s - loss: 253.8793 - mae: 9.0333 - val_loss: 105.6606 - val_mae: 6.7868 - 3s/epoch - 7ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 35.51285
# 425/425 - 3s - loss: 252.6613 - mae: 8.9847 - val_loss: 51.1173 - val_mae: 4.8064 - 3s/epoch - 7ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 35.51285
# 425/425 - 3s - loss: 244.9497 - mae: 8.9511 - val_loss: 68.8926 - val_mae: 3.5013 - 3s/epoch - 7ms/step
# Epoch 40/100
#
# Epoch 40: val_loss improved from 35.51285 to 33.91582, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 244.9816 - mae: 8.6903 - val_loss: 33.9158 - val_mae: 2.9677 - 3s/epoch - 7ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 33.91582
# 425/425 - 3s - loss: 239.3808 - mae: 8.7749 - val_loss: 57.4936 - val_mae: 4.2779 - 3s/epoch - 7ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 33.91582
# 425/425 - 3s - loss: 236.2000 - mae: 8.6600 - val_loss: 57.6876 - val_mae: 5.0113 - 3s/epoch - 7ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 33.91582
# 425/425 - 3s - loss: 236.9044 - mae: 8.6120 - val_loss: 35.2879 - val_mae: 3.2410 - 3s/epoch - 7ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 33.91582
# 425/425 - 3s - loss: 224.8537 - mae: 8.5511 - val_loss: 46.4132 - val_mae: 5.2000 - 3s/epoch - 7ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 33.91582
# 425/425 - 3s - loss: 226.7177 - mae: 8.5048 - val_loss: 89.6862 - val_mae: 6.3386 - 3s/epoch - 7ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 33.91582
# 425/425 - 3s - loss: 219.1015 - mae: 8.3613 - val_loss: 56.4976 - val_mae: 5.1988 - 3s/epoch - 7ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 33.91582
# 425/425 - 3s - loss: 220.4283 - mae: 8.3952 - val_loss: 46.4382 - val_mae: 4.6279 - 3s/epoch - 7ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 33.91582
# 425/425 - 3s - loss: 222.1045 - mae: 8.3736 - val_loss: 57.6127 - val_mae: 5.3471 - 3s/epoch - 7ms/step

# %% [markdown]
# # 학습과정 살펴보기

# %%
# 학습과정 그래프를 subplots와 twinx로 시각화
fig, ax1 = plt.subplots(figsize=(10,5))
ax1.plot(history.history['loss'], label='Train Loss', color='tab:blue')
ax1.plot(history.history['val_loss'], label='Val Loss', color='tab:cyan')
ax1.set_ylabel('Loss')
ax1.set_xlabel('Epoch')
ax1.legend(loc='upper left')
ax1.grid(True)
ax2 = ax1.twinx()
ax2.plot(history.history['mae'], label='Train mae', color='tab:orange')
ax2.plot(history.history['val_mae'], label='Val mae', color='tab:red')
ax2.set_ylabel('MAE')
ax2.legend(loc='upper right')
plt.title('LSTM Training Loss & MAE (twin y-axis)')
plt.show()

# %% [markdown]
# # 모델의 평가

# %%
loss_and_mae = model_lstm.evaluate(X_test,y_test)
# Out:
# 6842/6842 [==============================] - 18s 3ms/step - loss: 29.6785 - mae: 2.8767

# %%
print('loss :',round(loss_and_mae[0],3))
print('MAE :',round(loss_and_mae[1],2))
# Out:
# loss : 29.679
# MAE : 2.88

# %% [markdown]
# # 모델의 저장

# %%
# 모델, 스케일러, 인코더, feature 리스트 저장
model_lstm.save('best_lstm_model_lr.h5')
joblib.dump(scaler, 'ENCODER_SCALER/scaler.pkl')
joblib.dump(le, 'ENCODER_SCALER/labelencoders.pkl')
joblib.dump(feature_cols, 'ENCODER_SCALER/featurecols.pkl')
joblib.dump(num_cols, 'ENCODER_SCALER/numcols.pkl')
# Out:
# ['ENCODER_SCALER/numcols.pkl']

# %% [markdown]
# # 모델의 사용

# %%
def DBMS_find_1year_ago_of_tomorrow():
    """
    오늘 기준으로 '내일'의 1년 전(같은 시각) 데이터를 DB에서 조회하는 함수
    """
    import pymysql
    from dotenv import load_dotenv
    import os
    import pandas as pd
    from datetime import datetime, timedelta

    load_dotenv()
    host = os.getenv('host')
    user = os.getenv('user')
    password = os.getenv('password')
    database = os.getenv('database')
    port = int(os.getenv('port', 3306))

    # 현재 시각
    now = datetime.now()

    # 내일 같은 시각
    tomorrow = now + timedelta(days=1)

    # 1년 전 내일 같은 시각
    dt_1y = tomorrow.replace(year=tomorrow.year - 1)

    # DB 컬럼명에 맞게 쿼리 작성 (연, 월, 일, 시)
    query =f"""
        SELECT *
        FROM basic_data
        WHERE year = {dt_1y.year}
          AND month = {dt_1y.month}
          AND day = {dt_1y.day}
          AND hour = {dt_1y.hour}"""

    try:
        connection = pymysql.connect(
            host=host,
            user=user,
            password=password,
            database=database,
            port=port,
            charset='utf8mb4',
            cursorclass=pymysql.cursors.DictCursor
        )
        with connection.cursor() as cursor:
            cursor.execute(query)
            data = cursor.fetchall()
            result_df = pd.DataFrame(data)
#             print(result_df)
            return result_df
    except Exception as e:
        print('에러 발생:', e)
        return None
    finally:
        try:
            connection.close()
        except:
            pass

# 사용법
DBMS_find_1year_ago_of_tomorrow()
# Out:
#     year  month  day  hour district  ... precipitation  temperature humidity wind_speed  rental_count
# 0   2024      6   29    17      강남구  ...           6.0         23.8     97.0        2.7           237
# 1   2024      6   29    17      강동구  ...           5.0         23.8     95.0        4.0           438
# 2   2024      6   29    17      강북구  ...          10.0         23.7     95.0        1.0           137
# 3   2024      6   29    17      강서구  ...           6.5         24.0     94.0        3.6           993
# 4   2024      6   29    17      관악구  ...           6.5         23.4     94.0        2.0           202
# 5   2024      6   29    17      광진구  ...           6.0         23.8     97.0        2.7           421
# 6   2024      6   29    17      구로구  ...           5.5         24.4     94.0        2.8           370
# 7   2024      6   29    17      금천구  ...           5.5         24.4     94.0        2.8           113
# 8   2024      6   29    17      노원구  ...          10.0         23.7     95.0        1.0           600
# 9   2024      6   29    17      도봉구  ...          10.0         23.7     95.0        1.0           210
# 10  2024      6   29    17     동대문구  ...           6.5         24.1     96.0        1.9           295
# 11  2024      6   29    17      동작구  ...           6.0         24.8    100.0        2.6           165
# 12  2024      6   29    17      마포구  ...           6.5         24.5    100.0        1.9           489
# 13  2024      6   29    17     서대문구  ...           9.5         24.2     96.0        3.3           149
# 14  2024      6   29    17      서초구  ...           3.0         24.1     94.0        2.1           283
# 15  2024      6   29    17      성동구  ...           6.0         23.8     97.0        2.7           357
# 16  2024      6   29    17      성북구  ...           9.5         24.2     96.0        3.3           170
# 17  2024      6   29    17      송파구  ...           4.5         24.7     94.0        2.9           971
# 18  2024      6   29    17      양천구  ...           6.5         24.0     94.0        3.6           669
# 19  2024      6   29    17     영등포구  ...           6.5         24.5    100.0        1.9           773
# 20  2024      6   29    17      용산구  ...           6.0         23.8     97.0        2.7           169
# 21  2024      6   29    17      은평구  ...           6.5         23.4     96.0        1.3           226
# 22  2024      6   29    17      종로구  ...           9.5         24.2     96.0        3.3           272
# 23  2024      6   29    17       중구  ...           9.5         24.2     96.0        3.3           191
# 24  2024      6   29    17      중랑구  ...           7.0         24.0     96.0        1.3           237
#
# [25 rows x 15 columns]

# %%
def class_to_range(pred_class):
    # qcut 구간을 이용해서 문자로 반환
    bins = [1, 19, 37, 62, 93, 131, 180, 254, 393, 3258]
    pred_class = int(pred_class)
    left = int(bins[pred_class])
    right = int(bins[pred_class+1]) if pred_class+1 < len(bins) else '+'
    return f"{left} ~ {right}"

# %%
# 예측 함수
def predict_bike_demand(행정구, 강수, 습도, 풍속, 기온):
    """
    행정구명, 강수, 습도, 풍속, 기온을 입력받아
    해당 시간의 공공자전거 대여량 예측 클래스를 반환하는 함수
    """
    import pandas as pd
    import numpy as np
    import joblib
    from datetime import datetime, timedelta
    import holidays
    import tensorflow as tf

    le = joblib.load('ENCODER_SCALER/labelencoders.pkl')
    scaler = joblib.load('ENCODER_SCALER/scaler.pkl')
    feature_cols = joblib.load('ENCODER_SCALER/featurecols.pkl')
    num_cols = joblib.load('ENCODER_SCALER/numcols.pkl')
    model = tf.keras.models.load_model('best_lstm_model_lr.h5')

    now = datetime.now()
    년, 월, 일, 시 = now.year, now.month, now.day, now.hour
    요일 = now.weekday()
    주말구분 = 1 if 요일 >= 5 else 0
    kr_holidays = holidays.KR(years=[년])
    공휴일 = int(now.date() in kr_holidays)
    df_1y = DBMS_find_1year_ago_of_tomorrow()
    대여량_1년전 = df_1y[df_1y['district']==행정구].loc[:,'rental_count']
    총생활인구수_1년전 = df_1y[df_1y['district']==행정구].loc[:,'total_population']

    input_dict = {
        '행정구': le.transform([행정구])[0],
        '월': 월,
        '일': 일,
        '시': 시,
        '요일': 요일,
        '강수': 강수,
        '기온': 기온,
        '습도': 습도,
        '풍속': 풍속,
        '주말구분': 주말구분,
        '공휴일': 공휴일,
        '대여량_1년전': 대여량_1년전,
        '총생활인구수_1년전': 총생활인구수_1년전,
    }
    input_df = pd.DataFrame([input_dict])
    input_df[num_cols] = scaler.transform(input_df[num_cols])
    X_input = input_df[feature_cols].values
    X_input = np.expand_dims(X_input, axis=1)
    pred = model.predict(X_input,verbose=0)[0,0]
    return pred

# %%
pred = predict_bike_demand('강남구', 0.2, 60, 2.5, 21) # (행정구, 강수, 습도, 풍속, 기온)
print('25년 6월 29일 예측값', pred)
# Out:
# 25년 6월 29일 예측값 234.36023
